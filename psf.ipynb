# %% [markdown]
# # Auxtel PSF Example
#
# ### Links
#
# Before we get started, here are some potentially useful links.
#
# * [Piff main repo](https://github.com/rmjarvis/Piff)
# * [Piff documentation](http://rmjarvis.github.io/Piff/_build/html/index.html)
# * [DES Y3 PSF paper](https://ui.adsabs.harvard.edu/abs/2021MNRAS.501.1282J/abstract)
# * [ASCL 2102.024](https://ascl.net/2102.024)

# %% [markdown]
# ### Overview
#
# Piff is primarily designed to be run from the command line using a configuration file.  The (primary) executable is called `piffify`, so the most straightforward usage would be to run e.g.
# ```
# piffify config.yaml
# ```
#
# It is also typical to change individual configuration items on the command line that are meant to change for each exposure or each input image.  So perhaps a more typical usage would look something like
# ```
# piffify config.yaml input.image_file_name=D00572501_z_c01_r3624p01_immasked.fits.fz input.cat_file_name=D00572501_z_c01_r5473p01_piff.fits output.file_name=D00572501_z_c01.piff
# ```
# There may be additional items you might want to change besides these, but the names of input and output files are extremely common to set on the command line.

# %% [markdown]
# ### Config structure
#
# There are usually either 3 or 4 sections of the configuration file:
#
# 1. `input` defines all of the input data that Piff will use to constrain the PSF model.  At a minimum, this includes the image file name and the input catalog with positions of the stars.  It also defines what column names in the input catalog correspond to things like x,y or ra,dec, and what columsn are needed for other things like sky subtraction or star selection.
#
# 2. `select` defines how to select the candidate stars from the input catalog.  There are several ways to do this, but the easiest is some calculation based on stellar properties (columns from the input catalog).  There is also a size-magnitude selector which looks for the stellar locus in a size-magnitude diagram.  If this section is omitted, then all input objects that are not flagged are considered to be candidate stars.
#
# 3. `psf` defines the PSF model.  This typically involves two parts: the model profile at any given location, and how that profile should be interpolated across the field of view.  This section may also define an outlier rejection scheme to remove bad fits from further consideration.
#
# 4. `output` defines what file(s) to write to disk.  This may just be the Piff output file that defines the model (which other codes could then use to render PSF models), but it can also include additional plots and output catalogs in a `stats` field.  (More on that below.)

# %% [markdown]
# All fields have a `type` (possibly implicit if there is a useful default), which governs what other parameters are expected/allowed in that field.  This closely matches onto Python classes and the other items are like initialization parameters.
#
# For instance, models may be any of the following types currently:
# * Gaussian
# * Moffat
# * Kolmogorov
# * PixelGrid
# * Optical
#
# The currently implemented interpolation schemes are:
# * Mean
# * Polynomial
# * BasisPolynomial
# * kNNInterp
# * GPInterp
#
# This structure makes all parts of the code very modular.  It is easy to add a new type for some part of the calculation, which a user can then specify in their config file to change the behavior of Piff for their use case.

# %%
# Here is a relatively simple configuration for DES Y6 (Dark Energy Survey Year 6) data:

import yaml

config = """

input:
    
    # dir is optional.  If set, it applies to all file names here without an absolute path
    dir: .
        
    # Define the input image with the pixel data.
    # These data come with a bad pixel mask and a weight map.
    image_file_name: example_auxtel_image.fits
    image_hdu: 1
    badpix_hdu: 2
    
    # Note: The weight map is expeected to be an inverse variance map, containing only the non-signal
    #       part of the noise (sky, readnoise, dark current, etc.).  This is what DES provides.
    #       If you instead have a variance map (e.g. from LSST), you can tell Piff to invert it using
    #           invert_weight: True
    #       And if it includes Poisson noise from the signal (e.g. also LSST), Piff can remove it with
    #           remove_signal_from_weight: True
    weight_hdu: 3
        
    # Define the input catalog.
    cat_file_name: example_auxtel_catalog.fits
        
    # Either (x,y) or (ra,dec) are required columns saying where the objects are.
    x_col: XWIN_IMAGE
    y_col: YWIN_IMAGE
        
    # If flags is set, it will ignore flagged rows.
    flag_col: FLAGS
        
    # You can optionally specify any other columns you want to read.
    # These will be saved as additional properties of each star, which may be used in various ways.
    property_cols: [SPREAD_MODEL]
        
    # This sets how large a stamp to pull out of the full image for each input object.
    stamp_size: 25


select:
    # The default is to use all input objects as candidate stars.
    # Here we refine that a bit by selecting rows based on the SExtractor "SPREAD_MODEL" value.
    # SPREAD_MODEL is a measure of how much bigger an object is than the SExtractor software's estimate
    # of the PSF size, so objects with SPREAD_MODEL close to zero are likely stars.
    type: Properties
        
    # This can be any eval-able string.
    # As mentioned, here we use the SPREAD_MODEL property we read in from the input catalog.
    where: "np.abs(SPREAD_MODEL) < 3.e-4"
        
    # Mark 20% of stars as "reserve" stars.  Don't use them for fitting.                     
    # In machine learning lingo, this would be a validation set.
    reserve_frac: 0.2    
        
    # Specifying a seed makes the choice of reserve stars deterministic.  
    # Typically set on the command line, since you'd want this to be different for each image.
    seed: 1234   
        
    # Remove >3 sigma outlier in the HSM-measured size.
    # HSM (Hirata, Seljak and Mandelbaum) is an adaptive moment algorithm for measuring size and shapes, 
    # which is pretty stable and is included with GalSim.
    hsm_size_reject: 3   
        
    # Remove objects with estimated S/N < 50
    min_snr: 50          


psf:
    # The default "type" is "Simple", which just has a single model and interpolation scheme.
        
    model:
        # This model uses a gridded array of pixels, each with a free amplitude.
        # Here, it is a 21x21 grid of 0.27 arcsec pixels.
        type: PixelGrid
        scale: 0.27
        size: 21

    interp:
        # There are two different polynomial classes one can use for interpolation.
        # For models that can delay the final calculation of the parameters (which PixelGrid can),
        # the more complicated BasisPolynomial should normally be preferred.  It lets the model type
        # define the effect of the parameters, but the actual fit is delayed to use all the stars at
        # once combining the fit with the interpolation coefficients.  
        # This generally works better than completing the fit at each star and then interpolating,
        # but not all models can work in this mode.
        type: BasisPolynomial
        order: 3
            
    outliers:
        # After the 2nd and subsequent iterations, look for outliers whose fits have a bad chisq value.
        # This is really defined in terms of a chisq probability distribution falling below some value,
        # but for convenience we let that probability be set in terms of "nsigma" using the 1-d Gaussian
        # probability distribution meaning for n sigma.
        type: Chisq
        nsigma: 4

output:
    # For now, just output the file with the PSF solution.  We'll add more to this section below.
    dir: output
    file_name: D00572501_z_c01.piff  
"""

config = yaml.safe_load(config)

# %% [markdown]
# ### FItting the PSF model
#
# As mentioned above, the typical way to run Piff is from the command line.  However, one can also run the equivalent from within python using the `piff.piffify` function:

# %%
import piff

piff.piffify(config)
# Out:
# Getting wcs from image file ./example_auxtel_image.fits
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Getting wcs from image file ./example_auxtel_image.fits</pre>
# Reading image file ./example_auxtel_image.fits
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Reading image file ./example_auxtel_image.fits</pre>
# Warning: weight map has invalid negative-valued pixels. Taking them to be 0.0
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-error-color2)">ERROR</span>: Warning: weight map has invalid negative-valued pixels. Taking them to be 0.0</pre>
# Reading input catalog ./example_auxtel_catalog.fits.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Reading input catalog ./example_auxtel_catalog.fits.</pre>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 import piff
# ----> 3 piff.piffify(config)
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-6.0.0/lib/python3.10/site-packages/piff/config.py:168, in piffify(config, logger)
#     165     verbose = config.get('verbose', 1)
#     166     logger = setup_logger(verbose=verbose)
# --> 168 psf = process(config, logger)
#     170 # write it out to a file
#     171 output = Output.process(config['output'], logger=logger)
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-6.0.0/lib/python3.10/site-packages/piff/config.py:137, in process(config, logger)
#     134         config['select'][key] = config['input'].pop(key)
#     136 # read in the input images
# --> 137 objects, wcs, pointing = Input.process(config['input'], logger=logger)
#     138 stars = Select.process(config.get('select',{}), objects, logger=logger)
#     140 psf = PSF.process(config['psf'], logger=logger)
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-6.0.0/lib/python3.10/site-packages/piff/input.py:59, in Input.process(cls, config_input, logger)
#      56 input_handler = input_handler_class(config_input, logger)
#      58 # Creat a lit of StarData objects
# ---> 59 stars = input_handler.makeStars(logger)
#      61 if len(stars) == 0:
#      62     raise RuntimeError("No objects read in from input catalog(s).")
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-6.0.0/lib/python3.10/site-packages/piff/input.py:101, in Input.makeStars(self, logger)
#      94 args = [(self.image_kwargs[k], self.cat_kwargs[k], self.wcs_list[k], self.chipnums[k])
#      95         for k in range(self.nimages)]
#      96 kwargs = dict(stamp_size=self.stamp_size,
#      97               pointing=self.pointing, use_partial=self.use_partial,
#      98               invert_weight=self.invert_weight,
#      99               remove_signal_from_weight=self.remove_signal_from_weight)
# --> 101 all_stars = run_multi(self._makeStarsFromImage, self.nproc, raise_except=True,
#     102                       args=args, logger=logger, kwargs=kwargs)
#     104 # Concatenate the star lists into a single list
#     105 stars = [s for slist in all_stars if slist is not None for s in slist if slist]
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-6.0.0/lib/python3.10/site-packages/piff/util.py:265, in run_multi(func, nproc, raise_except, args, logger, kwargs)
#     263     k = kwargs[i]
#     264 try:
# --> 265     out = func(*args[i], logger=logger, **k)
#     266 except Exception as e:
#     267     if raise_except:
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-6.0.0/lib/python3.10/site-packages/piff/input.py:594, in InputFiles._makeStarsFromImage(image_kwargs, cat_kwargs, wcs, chipnum, stamp_size, pointing, use_partial, invert_weight, remove_signal_from_weight, logger)
#     587 @staticmethod
#     588 def _makeStarsFromImage(image_kwargs, cat_kwargs, wcs, chipnum,
#     589                         stamp_size, pointing, use_partial,
#     590                         invert_weight, remove_signal_from_weight,
#     591                         logger):
#     592     """Make "stars" from a single input image
#     593     """
# --> 594     image, wt, image_pos, extra_props = InputFiles._getRawImageData(
#     595             image_kwargs, cat_kwargs, wcs, invert_weight, remove_signal_from_weight, logger)
#     596     logger.info("Processing catalog %s with %d objects",chipnum,len(image_pos))
#     598     objects = []
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-6.0.0/lib/python3.10/site-packages/piff/input.py:562, in InputFiles._getRawImageData(image_kwargs, cat_kwargs, wcs, invert_weight, remove_signal_from_weight, logger)
#     559 # Update the wcs
#     560 image.wcs = wcs
# --> 562 image_pos, extra_props = InputFiles.readStarCatalog(
#     563         logger=logger, image=image, **cat_kwargs)
#     565 if remove_signal_from_weight:
#     566     # Subtract off the mean sky, since this isn't part of the "signal" we want to
#     567     # remove from the weights.
#     568     if 'sky' in extra_props:
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-6.0.0/lib/python3.10/site-packages/piff/input.py:846, in InputFiles.readStarCatalog(cat_file_name, cat_hdu, x_col, y_col, ra_col, dec_col, ra_units, dec_units, image, flag_col, skip_flag, use_flag, property_cols, sky_col, gain_col, sky, gain, satur, nstars, image_file_name, stamp_size, logger)
#     844 if flag_col is not None:
#     845     if flag_col not in cat.dtype.names:
# --> 846         raise ValueError("flag_col = %s is not a column in %s"%(flag_col,cat_file_name))
#     847     col = cat[flag_col]
#     848     if len(col.shape) == 2:
#
# ValueError: flag_col = FLAGS is not a column in ./example_auxtel_catalog.fits

# %% [markdown]
# One can then read in the output file using `piff.read`:

# %%
psf = piff.read('output/D00572501_z_c01.piff')

# %% [markdown]
# You can also skip round trip through the output file if you want by running `piff.process`, which runs all the same initial steps, but stops after the generation of the PSF model.  So the following is equivalent to the above two steps.
#
# Note that you can increase (or decrease) the verbosity of the output if desired.  You can supply a `logging.Logger` instance to any of these functions (as a `logger` parameter), or you can set `config['verbose']`.  The default is 1, which outputs a modest number of progress lines as the fit is proceeding.  Setting it to 0 will only output error messages.  Setting to 2 or 3 will output more information to help diagnose possible problems.

# %%
logger = piff.config.setup_logger(verbose=1)
psf2 = piff.process(config, logger=logger)
# Out:
# Getting wcs from image file 572501/D00572501_z_c01_r3624p01_immasked.fits.fz
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Getting wcs from image file 572501/D00572501_z_c01_r3624p01_immasked.fits.fz</pre>
# Reading image file 572501/D00572501_z_c01_r3624p01_immasked.fits.fz
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Reading image file 572501/D00572501_z_c01_r3624p01_immasked.fits.fz</pre>
# Reading input catalog 572501/D00572501_z_c01_r5473p01_piff.fits.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Reading input catalog 572501/D00572501_z_c01_r5473p01_piff.fits.</pre>
# Read a total of 248 objects from 1 image
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Read a total of 248 objects from 1 image</pre>
# Rejected a total of 2 stars out of 113 total candidates
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Rejected a total of 2 stars out of 113 total candidates</pre>
# Reserved 22 of 111 total stars
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Reserved 22 of 111 total stars</pre>
# Iteration 1: Fitting 89 stars
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Iteration 1: Fitting 89 stars</pre>
#              (22 stars are reserved)
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>:              (22 stars are reserved)</pre>
#              Total chisq = 19091.84 / 54976 dof
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>:              Total chisq = 19091.84 / 54976 dof</pre>
# Iteration 2: Fitting 89 stars
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Iteration 2: Fitting 89 stars</pre>
#              (22 stars are reserved)
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>:              (22 stars are reserved)</pre>
#              Total chisq = 18434.57 / 54976 dof
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>:              Total chisq = 18434.57 / 54976 dof</pre>

# %% [markdown]
# ### Using the PSF model
#
# Once you have a PSF model, the typical thing to do with it is to draw the PSF at some arbitrary locaion (e.g. the position of a galaxy).  The returned image is a GalSim Image instance.

# %%
import matplotlib.pyplot as plt

im1 = psf.draw(353.3, 409.6, center=True)

fig, ax = plt.subplots()
extent = (im1.bounds.xmin-0.5, im1.bounds.xmax+0.5, im1.bounds.ymin-0.5, im1.bounds.ymax+0.5)
c = ax.imshow(im1.array, origin='lower', extent=extent)
fig.colorbar(c)
plt.show()

# %%
import numpy as np
np.sum(im1.array)
# Out:
# 1.001932511370645

# %% [markdown]
# You can also give it an image to draw onto, rather than let it create one itself.  E.g. if you want the PSF centered in a pixel, you can give it an odd-sized image.

# %%
import galsim

im2 = psf.draw(353.3, 409.6, center=True, image=galsim.Image(25,25))

fig, ax = plt.subplots()
extent = (im2.bounds.xmin-0.5, im2.bounds.xmax+0.5, im2.bounds.ymin-0.5, im2.bounds.ymax+0.5)
c = ax.imshow(im2.array, origin='lower', extent=extent)
fig.colorbar(c)
plt.show()

# %% [markdown]
# You can also center it at other locations if you prefer.  The default is to center the profile at the same (x,y) value you give it for the interpolation position.  But you can also give an arbitrary position if you want something else.
#
# For instance, in the second case here, we draw onto an existing image where the center is at (0,0), and we want the same sub-pixel offset as the galaxy position.  Notice that this renders the same as drawing at the galaxy position where that is close to the center of the image.  Just the bounds of the images are different.

# %%
import galsim

im3=galsim.Image(25,25)
im3.setCenter(353, 409)

psf.draw(353.3, 409.6, image=im3)

fig, ax = plt.subplots(1,2, figsize=(11,4))
extent = (im3.bounds.xmin-0.5, im3.bounds.xmax+0.5, im3.bounds.ymin-0.5, im3.bounds.ymax+0.5)
c = ax[0].imshow(im3.array, origin='lower', extent=extent)
ax[0].set_title("Default centering")

im4 = im3.copy()
im4.setCenter(0,0)
psf.draw(353.3, 409.6, center=(0.3, 0.6), image=im3)
extent = (im4.bounds.xmin-0.5, im4.bounds.xmax+0.5, im4.bounds.ymin-0.5, im4.bounds.ymax+0.5)
c = ax[1].imshow(im4.array, origin='lower', extent=extent)
ax[1].set_title("Centered at 0.3, 0.6")
fig.colorbar(c, ax=list(ax.ravel()))
plt.show()

# %% [markdown]
# For some use cases, it may be preferable to access the PSF as a GalSim GSObject.  E.g. for forward modeling, you could then convolve it directly with your galaxy model.  Or you may want to draw it directly in Fourier space rather than in real space and then apply an FFT.
#
# The `get_profile` function doesn't just return the profile.  It returns a tuple `(profile, method)`.  The `method` is either 'fft' or 'no_pixel', corresponding to the method one would want to use if drawing this profile onto an image using the GalSim `drawImage` method.  This applies either to just directly drawing the PSF or first convolving the PSF by a galaxy (or other object profile) and then drawing.
#
# The method 'no_pixel' means that the profile model already includes convolution by the pixel response.  This is often called the "effective PSF".  Some PSF models can be set to model the PSF without the pixel convolution.  If that was done, then `get_profile` will return 'fft' for `method`.
#
# Here, we just look at what the PSF looks like in Fourier space by calling `drawKImage`.  Note that the `method` is 'no_pixel', which means that we are actually looking at the Fourier image of the effective PSF.

# %%
import numpy as np

profile, method = psf.get_profile(353.3, 409.6)

print('method = ',method)

kim = profile.drawKImage()

fig, ax = plt.subplots(1,2, figsize=(11,4))
extent = (kim.bounds.xmin-0.5, kim.bounds.xmax+0.5, kim.bounds.ymin-0.5, kim.bounds.ymax+0.5)
vmin = np.min(kim.array.real)
vmax = np.max(kim.array.real)
c = ax[0].imshow(kim.array.real, origin='lower', extent=extent, vmin=vmin, vmax=vmax) 
ax[1].imshow(kim.array.imag, origin='lower', extent=extent, vmin=vmin, vmax=vmax)
ax[0].set_title('KImage real')
ax[1].set_title('KImage imag')
fig.colorbar(c, ax=ax.ravel().tolist())
plt.show()
# Out:
# method =  no_pixel

# %% [markdown]
# Note that the imaginary part isn't exactly zero, even though it's hard to tell here.  A profile that is exactly $180^\circ$ rotationally symmetric has a purely real Fourier image.  This profile is close to that, but not quite, which is typical of realistic PSF images.  Here is the same thing, but using the imaginary part for the color range.

# %%
fig, ax = plt.subplots(1,2, figsize=(11,4))
vmin = np.min(kim.array.imag)
vmax = np.max(kim.array.imag)
c = ax[0].imshow(kim.array.real, origin='lower', extent=extent, vmin=vmin, vmax=vmax) 
ax[1].imshow(kim.array.imag, origin='lower', extent=extent, vmin=vmin, vmax=vmax)
ax[0].set_title('KImage real')
ax[1].set_title('KImage imag')
fig.colorbar(c, ax=ax.ravel().tolist())
plt.show()

# %% [markdown]
# ### Output stats
#
# In addtion to the regular output file with the computed model, Piff can also generate some additional files with various output statistics.  Most of these are in the form of plots, but there is also an HSM Catalog option with measurements of stars and models, which can be used for further analysis.  This is not an exhaustive list of possible output statistics, but it hopefully will give you a feel for the kinds of plots that are available.  See the full documentation for others.

# %%
config['output']['stats'] = yaml.safe_load(
"""
    -
        # Plot size and shape of the star, model, and difference between them as a function of position.
        type: TwoDHist
        file_name: twod_hist.png
    -
        # Show images of stars, models and differences.
        # By default, it selects a subset of all the stars, but one can force it to show all of them.
        type: Star
        file_name: star.png
    -
        # So-called "rho statistics".  These are correlation functions of the residuals, which are
        # relevant for weak lensing systematic errors.
        type: Rho
        min_sep: 30
        max_sep: 600
        sep_units: arcsec
        bin_size: 0.2
        file_name: rho.png
    -
        # A size-magnitude diagram of the selected stars.
        type: SizeMag
        file_name: size_mag.png
    -
        # An output catalog with size and shape measurements using the HSM adaptive moments algorithm.
        type: HSMCatalog
        file_name: hsm.fits
""")

# %% [markdown]
# If you've already run the PSF model, you can rerun just the stats using the other Piff executable, `plotify` or use the `piff.plotify` function from within Python.

# %%
piff.plotify(config)
# Out:
# Reading PSF from file output/D00572501_z_c01.piff
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Reading PSF from file output/D00572501_z_c01.piff</pre>
# Getting wcs from image file 572501/D00572501_z_c01_r3624p01_immasked.fits.fz
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Getting wcs from image file 572501/D00572501_z_c01_r3624p01_immasked.fits.fz</pre>
# Writing TwoDHistStats plot to file output/twod_hist.png
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Writing TwoDHistStats plot to file output/twod_hist.png</pre>
# Writing StarStats plot to file output/star.png
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Writing StarStats plot to file output/star.png</pre>
# Calculating rho statistics for 111 stars
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Calculating rho statistics for 111 stars</pre>
# Writing RhoStats plot to file output/rho.png
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Writing RhoStats plot to file output/rho.png</pre>
# Writing SizeMagStats plot to file output/size_mag.png
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Writing SizeMagStats plot to file output/size_mag.png</pre>
# Calculating shape histograms for 111 stars
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Calculating shape histograms for 111 stars</pre>
# Writing HSM catalog to file output/hsm.fits
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Writing HSM catalog to file output/hsm.fits</pre>

# %%
import PIL
from IPython import display
display.display(PIL.Image.open('output/twod_hist.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x900>

# %%
display.display(PIL.Image.open('output/star.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2100x1500>

# %%
display.display(PIL.Image.open('output/rho.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1000x500>

# %%
import fitsio

hsm = fitsio.read('output/hsm.fits')
print(hsm.dtype)
# Out:
# [('u', '>f8'), ('v', '>f8'), ('x', '>f8'), ('y', '>f8'), ('ra', '>f8'), ('dec', '>f8'), ('flux', '>f8'), ('reserve', '?'), ('flag_data', '>i8'), ('flag_model', '>i8'), ('T_data', '>f8'), ('g1_data', '>f8'), ('g2_data', '>f8'), ('T_model', '>f8'), ('g1_model', '>f8'), ('g2_model', '>f8'), ('chipnum', '>f8'), ('SPREAD_MODEL', '>f8'), ('FLAGS', '>f8'), ('snr', '>f8')]

# %%
display.display(PIL.Image.open('output/size_mag.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600>

# %% [markdown]
# ### Size-magnitude selection
#
# The size-magnitude output plot gets rather more interesting if you also use the size-magnitude selector to pick out which stars to use.  This selector expects the input catalog to include both stars and galaxies.  It then looks for a locus of stars that are all the same size at bright magnitudes, and follows it to fainter magnitudes until it melds into the galaxy locus.
#
# Let's switch to an input catalog that includes all detections, not just some selection of star-like objects and have Piff select the probable stars from that using the SizeMag selector.

# %%
config['select'] = yaml.safe_load(
"""
    type: SizeMag
    
    # SizeMag can optionally take a different selctor as an initial guess.
    # If you have something reasonable to use, this is recommended, but there is a default
    # crude initial selector it will use if you don't have any other option.
    initial_select:
        type: Properties
        where: "np.abs(SPREAD_MODEL) < 3.e-4"

    # All selection schemes can apply further rejection steps to remove obviously bad stars.
    hsm_size_reject: 4
    min_snr: 50
    
    # And again, let's reserve 20% of the stars for validation tests.
    reserve_frac: 0.2
    seed: 1234
""")
config['input']['cat_file_name'] = "D00572501_z_c01_r3624p01_red-fullcat.fits"
config['input']['cat_hdu'] = 2

# %%
piff.piffify(config)
# Out:
# Getting wcs from image file 572501/D00572501_z_c01_r3624p01_immasked.fits.fz
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Getting wcs from image file 572501/D00572501_z_c01_r3624p01_immasked.fits.fz</pre>
# Reading image file 572501/D00572501_z_c01_r3624p01_immasked.fits.fz
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Reading image file 572501/D00572501_z_c01_r3624p01_immasked.fits.fz</pre>
# Reading input catalog 572501/D00572501_z_c01_r3624p01_red-fullcat.fits.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Reading input catalog 572501/D00572501_z_c01_r3624p01_red-fullcat.fits.</pre>
# Object at position 1986.088361,42.082292 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1986.088361,42.082292 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1992.648301,83.843551 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1992.648301,83.843551 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 423.552589,206.076870 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 423.552589,206.076870 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1465.219317,269.561195 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1465.219317,269.561195 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1079.020395,444.939105 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1079.020395,444.939105 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 254.078617,362.664071 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 254.078617,362.664071 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1292.020792,711.706583 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1292.020792,711.706583 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1185.571738,1005.532534 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1185.571738,1005.532534 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1800.961841,1314.240202 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1800.961841,1314.240202 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1237.781845,1236.290709 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1237.781845,1236.290709 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 399.288014,1623.664574 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 399.288014,1623.664574 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1116.923021,1794.524510 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1116.923021,1794.524510 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 957.107668,2112.568709 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 957.107668,2112.568709 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 35.419196,2042.623538 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 35.419196,2042.623538 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 47.291361,2077.963313 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 47.291361,2077.963313 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 854.640341,2289.910388 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 854.640341,2289.910388 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1732.571055,2385.942864 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1732.571055,2385.942864 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 220.901060,2561.043262 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 220.901060,2561.043262 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 831.094153,2889.618703 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 831.094153,2889.618703 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1543.927109,2921.495410 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1543.927109,2921.495410 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 827.427746,3022.659360 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 827.427746,3022.659360 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 959.363539,3113.099535 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 959.363539,3113.099535 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 106.921908,3138.582103 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 106.921908,3138.582103 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1954.040691,3082.997018 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1954.040691,3082.997018 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1884.586031,3086.374688 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1884.586031,3086.374688 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1807.819889,3092.265660 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1807.819889,3092.265660 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1981.585423,3099.543030 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1981.585423,3099.543030 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 453.299395,3125.301773 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 453.299395,3125.301773 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1204.813014,3102.406672 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1204.813014,3102.406672 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1259.023038,3105.956101 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1259.023038,3105.956101 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 190.503278,3144.885636 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 190.503278,3144.885636 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1959.317288,4048.918138 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1959.317288,4048.918138 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 909.685655,3760.596003 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 909.685655,3760.596003 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 421.616824,3479.570548 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 421.616824,3479.570548 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1299.958040,3121.149071 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1299.958040,3121.149071 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1826.358166,3108.969892 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1826.358166,3108.969892 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 786.508070,3119.319647 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 786.508070,3119.319647 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1112.967570,3128.624423 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1112.967570,3128.624423 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 76.762673,3153.454016 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 76.762673,3153.454016 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 442.780432,3146.477699 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 442.780432,3146.477699 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 209.494601,3136.050644 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 209.494601,3136.050644 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 364.280099,3125.718657 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 364.280099,3125.718657 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 54.663719,3149.764916 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 54.663719,3149.764916 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 1939.708367,4006.216722 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 1939.708367,4006.216722 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 76.641389,4033.689272 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 76.641389,4033.689272 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Object at position 182.221152,3897.587311 is completely masked.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Object at position 182.221152,3897.587311 is completely masked.</pre>
# Skipping this object.
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Skipping this object.</pre>
# Read a total of 2098 objects from 1 image
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Read a total of 2098 objects from 1 image</pre>
# Selecting stars according to locus in size-magnitude diagram
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Selecting stars according to locus in size-magnitude diagram</pre>
# SizeMag selection found 124 likely stars
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: SizeMag selection found 124 likely stars</pre>
# Rejected a total of 0 stars out of 124 total candidates
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Rejected a total of 0 stars out of 124 total candidates</pre>
# Reserved 24 of 124 total stars
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Reserved 24 of 124 total stars</pre>
# Iteration 1: Fitting 100 stars
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Iteration 1: Fitting 100 stars</pre>
#              (24 stars are reserved)
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>:              (24 stars are reserved)</pre>
#              Total chisq = 3164.36 / 61689 dof
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>:              Total chisq = 3164.36 / 61689 dof</pre>
# Iteration 2: Fitting 100 stars
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Iteration 2: Fitting 100 stars</pre>
#              (24 stars are reserved)
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>:              (24 stars are reserved)</pre>
#              Total chisq = 2841.95 / 61689 dof
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>:              Total chisq = 2841.95 / 61689 dof</pre>
# Writing PSF to file output/D00572501_z_c01.piff
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Writing PSF to file output/D00572501_z_c01.piff</pre>
# Writing TwoDHistStats plot to file output/twod_hist.png
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Writing TwoDHistStats plot to file output/twod_hist.png</pre>
# Writing StarStats plot to file output/star.png
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Writing StarStats plot to file output/star.png</pre>
# Calculating rho statistics for 124 stars
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Calculating rho statistics for 124 stars</pre>
# Writing RhoStats plot to file output/rho.png
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Writing RhoStats plot to file output/rho.png</pre>
# Writing SizeMagStats plot to file output/size_mag.png
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Writing SizeMagStats plot to file output/size_mag.png</pre>
# Calculating shape histograms for 124 stars
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Calculating shape histograms for 124 stars</pre>
# Writing HSM catalog to file output/hsm.fits
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">piff</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Writing HSM catalog to file output/hsm.fits</pre>

# %%
display.display(PIL.Image.open('output/size_mag.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600>
